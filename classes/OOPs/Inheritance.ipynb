# %% [markdown]
#             Pyhton does not support high security like java. here, we can access the protected member and private member in outside the class by using following ways :
#             1. To access the protected member obj._protectedmembername
#             2. To access the private member by using name mangling - obj._classname.__privatemembername
#
#             - The advantage of encapsulation is it can provide the security for data as well as for functionalities.
#
# # Inheritance :
#
#             In python, A class get properties from another class this process called as 'Inheritance'.
#
#             - A child class is inherited from parent class.
#
#             Types of Inheritance :
#
#                         1. single inheritance
#                         2. multi level inheritance
#                         3. multiple inheriatance
#                         4. Hierarichal inheritance
#                         5. Hybrid inheritance
#
# ###         1. Single Inheritance :
#
#                         A child class get properties from single parent class. this is called as single inheritance.
#
#                         Syntax :
#
#                                 class parent_class_name :
#                                             # attributes
#                                             # methods
#                                 class child_class (parent _class_name):
#                                             # attributes
#                                             # methods
#
# ###         2. multi level Inheritance :
#
#                         A class(child class) get properties from some another class (parent class), that class also get properties from some another class (grand parent class). this is called as multi level inheritance.
#
#                         Syntax :
#
#                                 class grnad_parent_class_name :
#                                             # attributes
#                                             # methods
#                                 class parent_class_name (Grnad_parent_classs) :
#                                             # attributes
#                                             # methods
#                                 class child_class (parent _class_name):
#                                             # attributes
#                                             # methods
#
# ###         3. multiple Inheritance :
#
#                         A single class(child class) get properties from multiple classes (parent classes). this is called as multiple inheritance.
#
#                         Syntax :
#
#                                 class parent_class_name1 :
#                                             # attributes
#                                             # methods
#                                 class parent_class_name2 :
#                                             # attributes
#                                             # methods
#                                 class child_class (parent_class_name1,parent_class_name2):
#                                             # attributes
#                                             # methods
#
# ###         4. Hierarichal Inheritance :
#
#                         multiple classes(child classes) get properties from single class (parent class). this is called as Hierarichal inheritance.
#
#                         Syntax :
#
#                                 class parent_class_name :
#                                             # attributes
#                                             # methods
#                                 class child_class_name1 (parent_class_name):
#                                             # attributes
#                                             # methods
#                                 class child_class_name2 (parent_class_name):
#                                             # attributes
#                                             # methods
#
# ###         5. Hybrid Inheritance :
#
#                         It is a combination of two or more types of inheritances. this is called as Hybrid inheritance.

# %%
# single Inheritance
# Without child class implementation
# when child class dont have constructor, in that case parent class constructor behaves like child class constructor
class Person:
    def __init__(self, name, age, gender):
        self.name = name
        self.age = age
        self.gender = gender
    def details(self):
        return f"My name is {self.name}. Iam a {self.age} Years old."
class Student(Person):
    pass

s = Student('Raju',21,'Male')
print(s.details())
# Out:
# My name is Raju. Iam a 21 Years old.

# %%
# single Inheritance
# With child class implementation
# when child class have constructor it will behave like child class constructor, parent class constructor behaves like parent class constructor. so we can pass the values to child class constructor
class Person:
    def __init__(self, name, age, gender):
        self.name = name
        self.age = age
        self.gender = gender
    def details(self):
        return f"My name is {self.name}. Iam a {self.age} Years old and gender is {self.gender}."
class Student(Person):
    def __init__(self,stdid,name,age,branch):
        self.name = name
        self.stdid = stdid
        self.age = age
        # self.gender = gender
        self.branch = branch

s = Student(538,'Raju',21,'CSE')
print(s.name)
# print(s.gender)    # It rises attribute error because student reference does not contains gender attribute
print(s.age)
# Out:
# Raju
# 21

# %%
# single Inheritance
# With child class implementation
# when child class have constructor it will behave like child class constructor, parent class constructor behaves like parent class constructor. so we can pass the values to child class constructor
class Person:
    def __init__(self, name, age, gender):
        self.name = name
        self.age = age
        self.gender = gender
    def details(self):
        return f"My name is {self.name}. Iam a {self.age} Years old and gender is {self.gender}."
class Student(Person):
    def __init__(self,stdid,name,age,gender,branch):
        # self.name = name
        super().__init__(name,age,gender)
        self.stdid = stdid
        # self.age = age
        # self.gender = gender
        self.branch = branch

s = Student(538,'Raju',21,'Male','CSE')
print(s.name)
print(s.gender)    
print(s.age)
print(s.details())
# Out:
# Raju
# Male
# 21
# My name is Raju. Iam a 21 Years old and gender is Male.

# %%
# 2. multi level Inheritance

class Student:
    def __init__(self, name, age, stdid,gender):
        self.name = name
        self.age = age
        self.stdid = stdid
        self.gender = gender
    def details(self):
        return f"My name is {self.name}, My student id is {self.stdid} and iam {self.age} years old."
class College(Student):
    def __init__(self, name, stdid, marks):
        super().__init__(name,stdid)
        self.marks = marks
    def displaymarks(self):
        return f"My name is {self.name}, My student id is {self.stdid} and I got {self.marks}."
class Engineering(College):
    def __init__(self, name, stdid,college,cgpa):
        super().__init__(name, stdid)
        self.college = college
        self.cgpa = cgpa
    def displaycollege(self):
        return f"My name is {self.name} My college name is {self.college} and my cgpa is {self.cgpa}"
s = Engineering('Raju',22,538,'Male',555)
# print(s.details())
# print(s.displaymarks())
print(s.displaycollege())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 24
#      20         self.college = college
#      21         self.cgpa = cgpa
#      22     def displaycollege(self):
#      23         return f"My name is {self.name} My college name is {self.college} and my cgpa is {self.cgpa}"
# ---> 24 s = Engineering('Raju',22,538,'Male',555)
#      25 # print(s.details())
#      26 # print(s.displaymarks())
#      27 print(s.displaycollege())
#
# TypeError: Engineering.__init__() takes 5 positional arguments but 6 were given

# %%
# 2. multi level Inheritance

class Student:
    def __init__(self, name, age, stdid,gender):
        self.name = name
        self.age = age
        self.stdid = stdid
        self.gender = gender
    def details(self):
        return f"My name is {self.name}, My student id is {self.stdid} and iam {self.age} years old."
class College(Student):
    def __init__(self, name, stdid, marks,age,gender):
        super().__init__(name,age,stdid,gender)
        self.marks = marks
    def displaymarks(self):
        return f"My name is {self.name}, My student id is {self.stdid} and I got {self.marks} Marks."
class Engineering(College):
    def __init__(self, name,age,gender,stdid,marks,college,cgpa):
        super().__init__(name, stdid,marks,age,gender)
        self.college = college
        self.cgpa = cgpa
    def displaycollege(self):
        return f"My name is {self.name} My college name is {self.college} and my cgpa is {self.cgpa}"
s = Engineering('Raju',21,'Male',538,555,"SASI",8.1)
print(s.details())
print(s.displaymarks())
print(s.displaycollege())
# Out:
# My name is Raju, My student id is 538 and iam 21 years old.
# My name is Raju, My student id is 538 and I got 555 Marks.
# My name is Raju My college name is SASI and my cgpa is 8.1

# %%
# 3. Multiple Inheritance
class Personal:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def details(self):
        return f"My name is {self.name} and my age is {self.age}"

class Education:
    def __init__(self, stdid, college):
        self.stdid = stdid
        self.college = college
    def details1(self):
        return f"My student ID is {self.stdid} and iam from {self.college} college"
class Information(Personal, Education):
    def __init__(self, name, age, stdid, college, marks):
        super().__init__(name, age, stdid, college)
        self.marks = marks
    def info(self):
        return f"My name is {self.name}, Iam {self.age} Years old, Mystudent ID is {self.stdid}, My college name is {self.college} and I got {self.marks} marks."

s = Information("Raju",22,538,"SASI",555)
print(s.info())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 23
#      19         self.marks = marks
#      20     def info(self):
#      21         return f"My name is {self.name}, Iam {self.age} Years old, Mystudent ID is {self.stdid}, My college name is {self.college} and I got {self.marks} marks."
#      22
# ---> 23 s = Information("Raju",22,538,"SASI",555)
#      24 print(s.info())
#
# Cell In[12], line 18, in Information.__init__(self, name, age, stdid, college, marks)
#      17     def __init__(self, name, age, stdid, college, marks):
# ---> 18         super().__init__(name, age, stdid, college)
#      19         self.marks = marks
#
# TypeError: Personal.__init__() takes 3 positional arguments but 5 were given

# %%
# 4. Hierarichal Inheritance
class Mobile : 
    def __init__(self, shape, purpose):
        self.shape = shape
        self.purpose = purpose
    def det(self):
        return f"The shape of the mobile is {self.shape} and it is used for {self.purpose}."
class Mi(Mobile):
    def __init__(self, shape, purpose, name, model):
        super().__init__(shape,purpose)
        self.name = name
        self.model = model
    def det1(self):
        return f"The mobile is from Brand {self.name} and model is {self.model}. The shape of the mobile is {self.shape} and it is used for {self.purpose}."
class Oppo(Mobile):
    def __init__(self, shape, purpose, name, model,price):
        super().__init__(shape,purpose)
        self.name = name
        self.model = model
        self.price = price
    def det2(self):
        return f"The mobile is from Brand {self.name} and model is {self.model}. The shape of the mobile is {self.shape} and it is used for {self.purpose} and the price is {self.price}."

s1 = Mi("Square","Browsing","Redmi","Note 13 5G")
s2 = Oppo("Square","Browsing","Oppo","Reno 6 5G",2000)

print(s1.det())
print(s1.det1())
print(s2.det2())
# Out:
# The shape of the mobile is Square and it is used for Browsing.
# The mobile is from Brand Redmi and model is Note 13 5G. The shape of the mobile is Square and it is used for Browsing.
# The mobile is from Brand Oppo and model is Reno 6 5G. The shape of the mobile is Square and it is used for Browsing and the price is 2000.
