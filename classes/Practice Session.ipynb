# %%
name = input()
print(name)
# Out:
#  ksdbhjbjgnklnjb
# ksdbhjbjgnklnjb

# %%
marks = float(input())
print(marks)
# Out:
#  82487.8974
# 82487.8974

# %%
a = float(input())
b = float(input())
c = float(input())
d = float(input())
e = float(input())

print(a)
print(b)
print(c)
print(d)
print(e)
print(a+b+c+d+e)
print((a+b+c+d+e)/5)
# Out:
#  12
#  34
#  2
#  4
#  34
# 12.0
# 34.0
# 2.0
# 4.0
# 34.0
# 86.0
# 17.2
