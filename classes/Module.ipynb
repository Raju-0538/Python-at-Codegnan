# %% [markdown]
# # Module :
#
#      A module is .py file and it consists of variables , functions, and classes.
#
#      - can use the one module code in some another module by importing the module.
