# %% [markdown]
# # Modules :
#
#     Types of Modules :
#
#             1. User defined Modules
#             2. Builtin Modules
#
# ### 1. Userdefined Modules :
#
#             The modules are defined by the user or programmer , those modules are called as Userdefined modules.
#
# ### 2. Builtin Modules :
#
#             The modules which are provided by the python software is called as Builtin modules.
#
#             Ex:
#
#                 - Math                          -> Advanced Mathematical operations
#                 - random                        -> To generate random numbers
#                 - os                            -> File or Directory creation
#                 - sys                           -> Related to Interpreter
#                 - pandas                        -> Data Manipulation purpose
#                 - numpy                         -> Numerical calculations
#                 - matplot lib & seaborn         -> Data Visualization
#                 - scikit learn                  -> For Machine Learning Models

# %%
import math,random,os,sys

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
print(math.ceil(4.25))    # It returns the upperbound integer value
print(math.floor(4.25))   # It returns the lowerbound integer value
print(math.factorial(5))  # It returns the factorial of a number
print(math.gcd(10,6,4))   # It returns the GCD of a number
print(math.lcm(10,6,4))   # It returns the LCM of a number
print(math.pow(10,2))     # It returns the float type of {a} power {b} value
print(math.sqrt(9))       # It will return the square root value of a number
print(math.log10(2))      # It will return  the log10 value of a number
# Out:
# 5
# 4
# 120
# 2
# 60
# 100.0
# 3.0
# 0.3010299956639812

# %%
print(random.random())     # It generates the random number between 0 to 9
print(random.randint(1,6)) # It generate a random value from 1 to 6
print(random.randint(1000,9999))   # For OTP purpose
print(random.choice(['A',1,2,3,4,5,6,7,8,9,'J','Q','K']))   # This function returns the random value from given sequence
print(random.choices(['A',1,2,3,4,5,6,7,8,9,'J','Q','K'],k=3))   # This function returns the random values from given sequence based on the k value
arr = ['A',1,2,3,4,5,6,7,8,9,'J','Q','K']
random.shuffle(arr)        # It will shuffle the values
print(arr)
# Out:
# 0.9622130504360505
# 4
# 8071
# 5
# [1, 'J', 'A']
# [1, 'J', 3, 'A', 'Q', 5, 'K', 7, 8, 2, 4, 9, 6]

# %%
rolls = 0
count = 0
a = int(input())
while(count<a):
    input("Press Enter to Throw the Die")
    ran = random.randint(1,6)
    rolls += 1
    if count+ran <= a:
        count += ran
        print(f"Throw : {rolls}")
    print(f"Throw Value : {ran}")
    print(f"Your total After throw : {count}")
print(f"Total Rolls : {rolls}")
# Out:
#  102
# Press Enter to Throw the Die
# Throw : 1
# Throw Value : 6
# Your total After throw : 6
# Press Enter to Throw the Die
# Throw : 2
# Throw Value : 6
# Your total After throw : 12
# Press Enter to Throw the Die
# Throw : 3
# Throw Value : 4
# Your total After throw : 16
# Press Enter to Throw the Die
# Throw : 4
# Throw Value : 1
# Your total After throw : 17
# Press Enter to Throw the Die
# Throw : 5
# Throw Value : 4
# Your total After throw : 21
# Press Enter to Throw the Die
# Throw : 6
# Throw Value : 4
# Your total After throw : 25
# Press Enter to Throw the Die
# Throw : 7
# Throw Value : 3
# Your total After throw : 28
# Press Enter to Throw the Die
# Throw : 8
# Throw Value : 5
# Your total After throw : 33
# Press Enter to Throw the Die
# Throw : 9
# Throw Value : 1
# Your total After throw : 34
# Press Enter to Throw the Die
# Throw : 10
# Throw Value : 2
# Your total After throw : 36
# Press Enter to Throw the Die
# Throw : 11
# Throw Value : 2
# Your total After throw : 38
# Press Enter to Throw the Die
# Throw : 12
# Throw Value : 5
# Your total After throw : 43
# Press Enter to Throw the Die
# Throw : 13
# Throw Value : 3
# Your total After throw : 46
# Press Enter to Throw the Die
# Throw : 14
# Throw Value : 1
# Your total After throw : 47
# Press Enter to Throw the Die
# Throw : 15
# Throw Value : 1
# Your total After throw : 48
# Press Enter to Throw the Die
# Throw : 16
# Throw Value : 1
# Your total After throw : 49
# Press Enter to Throw the Die
# Throw : 17
# Throw Value : 5
# Your total After throw : 54
# Press Enter to Throw the Die
# Throw : 18
# Throw Value : 5
# Your total After throw : 59
# Press Enter to Throw the Die
# Throw : 19
# Throw Value : 1
# Your total After throw : 60
# Press Enter to Throw the Die
# Throw : 20
# Throw Value : 2
# Your total After throw : 62
# Press Enter to Throw the Die
# Throw : 21
# Throw Value : 1
# Your total After throw : 63
# Press Enter to Throw the Die
# Throw : 22
# Throw Value : 3
# Your total After throw : 66
# Press Enter to Throw the Die
# Throw : 23
# Throw Value : 6
# Your total After throw : 72
# Press Enter to Throw the Die
# Throw : 24
# Throw Value : 2
# Your total After throw : 74
# Press Enter to Throw the Die
# Throw : 25
# Throw Value : 3
# Your total After throw : 77
# Press Enter to Throw the Die
# Throw : 26
# Throw Value : 2
# Your total After throw : 79
# Press Enter to Throw the Die
# Throw : 27
# Throw Value : 3
# Your total After throw : 82
# Press Enter to Throw the Die
# Throw : 28
# Throw Value : 6
# Your total After throw : 88
# Press Enter to Throw the Die
# Throw : 29
# Throw Value : 3
# Your total After throw : 91
# Press Enter to Throw the Die
# Throw : 30
# Throw Value : 1
# Your total After throw : 92
# Press Enter to Throw the Die
# Throw : 31
# Throw Value : 2
# Your total After throw : 94
# Press Enter to Throw the Die
# Throw : 32
# Throw Value : 6
# Your total After throw : 100
# Press Enter to Throw the Die
# Throw : 33
# Throw Value : 2
# Your total After throw : 102
# Total Rolls : 33

# %%
import random
rolls = 0
count = 0
snakes = {32:5,44:22,33:3,99:1,91:88,73:23,64:43,40:20,50:30}
laders = {38:95,35:90,11:43,77:92,55:74,46:80,62:79,13:67}
a = 100
while(count<a):
    input("Press Enter to Throw the Die")
    ran = random.randint(1,6)
    rolls += 1
    if count+ran <= a:
        count += ran
        if count in snakes:
            print(f"In {count} there is a snake so you need to start from {snakes[count]}")
            count = snakes[count]
            
        elif count in laders:
            print(f"In {count} there is a Ladder so you need to start from {laders[count]}")
            count = laders[count]
            
        print(f"Throw : {rolls}")
    print(f"Throw Value : {ran}")
    print(f"Your Position After throw : {count}")
print(f"Total Rolls : {rolls}")
# Out:
# Press Enter to Throw the Die
# Throw : 1
# Throw Value : 3
# Your Position After throw : 3
# Press Enter to Throw the Die
# Throw : 2
# Throw Value : 5
# Your Position After throw : 8
# Press Enter to Throw the Die
# In 11 there is a Ladder so you need to start from 43
# Throw : 3
# Throw Value : 3
# Your Position After throw : 43
# Press Enter to Throw the Die
# Throw : 4
# Throw Value : 4
# Your Position After throw : 47
# Press Enter to Throw the Die
# In 50 there is a snake so you need to start from 30
# Throw : 5
# Throw Value : 3
# Your Position After throw : 30
# Press Enter to Throw the Die
# Throw : 6
# Throw Value : 4
# Your Position After throw : 34
# Press Enter to Throw the Die
# In 38 there is a Ladder so you need to start from 95
# Throw : 7
# Throw Value : 4
# Your Position After throw : 95
# Press Enter to Throw the Die
# In 99 there is a snake so you need to start from 1
# Throw : 8
# Throw Value : 4
# Your Position After throw : 1
# Press Enter to Throw the Die
# Throw : 9
# Throw Value : 4
# Your Position After throw : 5
# Press Enter to Throw the Die
# Throw : 10
# Throw Value : 5
# Your Position After throw : 10
# Press Enter to Throw the Die
# In 13 there is a Ladder so you need to start from 67
# Throw : 11
# Throw Value : 3
# Your Position After throw : 67
# Press Enter to Throw the Die
# Throw : 12
# Throw Value : 3
# Your Position After throw : 70
# Press Enter to Throw the Die
# Throw : 13
# Throw Value : 5
# Your Position After throw : 75
# Press Enter to Throw the Die
# In 77 there is a Ladder so you need to start from 92
# Throw : 14
# Throw Value : 2
# Your Position After throw : 92
# Press Enter to Throw the Die
# Throw : 15
# Throw Value : 6
# Your Position After throw : 98
# Press Enter to Throw the Die
# Throw Value : 6
# Your Position After throw : 98
# Press Enter to Throw the Die
# Throw Value : 6
# Your Position After throw : 98
# Press Enter to Throw the Die
# Throw Value : 6
# Your Position After throw : 98
# Press Enter to Throw the Die
# Throw Value : 5
# Your Position After throw : 98
# Press Enter to Throw the Die
# Throw Value : 4
# Your Position After throw : 98
# Press Enter to Throw the Die
# In 99 there is a snake so you need to start from 1
# Throw : 21
# Throw Value : 1
# Your Position After throw : 1
# Press Enter to Throw the Die
# Throw : 22
# Throw Value : 5
# Your Position After throw : 6
# Press Enter to Throw the Die
# Throw : 23
# Throw Value : 3
# Your Position After throw : 9
# Press Enter to Throw the Die
# Throw : 24
# Throw Value : 3
# Your Position After throw : 12
# Press Enter to Throw the Die
# Throw : 25
# Throw Value : 2
# Your Position After throw : 14
# Press Enter to Throw the Die
# Throw : 26
# Throw Value : 1
# Your Position After throw : 15
# Press Enter to Throw the Die
# Throw : 27
# Throw Value : 4
# Your Position After throw : 19
# Press Enter to Throw the Die
# Throw : 28
# Throw Value : 1
# Your Position After throw : 20
# Press Enter to Throw the Die
# Throw : 29
# Throw Value : 4
# Your Position After throw : 24
# Press Enter to Throw the Die
# Throw : 30
# Throw Value : 5
# Your Position After throw : 29
# Press Enter to Throw the Die
# Throw : 31
# Throw Value : 5
# Your Position After throw : 34
# Press Enter to Throw the Die
# In 35 there is a Ladder so you need to start from 90
# Throw : 32
# Throw Value : 1
# Your Position After throw : 90
# Press Enter to Throw the Die
# Throw : 33
# Throw Value : 3
# Your Position After throw : 93
# Press Enter to Throw the Die
# In 99 there is a snake so you need to start from 1
# Throw : 34
# Throw Value : 6
# Your Position After throw : 1
# Press Enter to Throw the Die
# Throw : 35
# Throw Value : 1
# Your Position After throw : 2
# Press Enter to Throw the Die
# Throw : 36
# Throw Value : 2
# Your Position After throw : 4
# Press Enter to Throw the Die
# Throw : 37
# Throw Value : 2
# Your Position After throw : 6
# Press Enter to Throw the Die
# Throw : 38
# Throw Value : 2
# Your Position After throw : 8
# Press Enter to Throw the Die
# Throw : 39
# Throw Value : 2
# Your Position After throw : 10
# Press Enter to Throw the Die
# Throw : 40
# Throw Value : 6
# Your Position After throw : 16
# Press Enter to Throw the Die
# Throw : 41
# Throw Value : 3
# Your Position After throw : 19
# Press Enter to Throw the Die
# Throw : 42
# Throw Value : 4
# Your Position After throw : 23
# Press Enter to Throw the Die
# Throw : 43
# Throw Value : 4
# Your Position After throw : 27
# Press Enter to Throw the Die
# Throw : 44
# Throw Value : 1
# Your Position After throw : 28
# Press Enter to Throw the Die
# In 33 there is a snake so you need to start from 3
# Throw : 45
# Throw Value : 5
# Your Position After throw : 3
# Press Enter to Throw the Die
# Throw : 46
# Throw Value : 2
# Your Position After throw : 5
# Press Enter to Throw the Die
# Throw : 47
# Throw Value : 3
# Your Position After throw : 8
# Press Enter to Throw the Die
# Throw : 48
# Throw Value : 6
# Your Position After throw : 14
# Press Enter to Throw the Die
# Throw : 49
# Throw Value : 2
# Your Position After throw : 16
# Press Enter to Throw the Die
# Throw : 50
# Throw Value : 6
# Your Position After throw : 22
# Press Enter to Throw the Die
# Throw : 51
# Throw Value : 4
# Your Position After throw : 26
# Press Enter to Throw the Die
# Throw : 52
# Throw Value : 5
# Your Position After throw : 31
# Press Enter to Throw the Die
# In 33 there is a snake so you need to start from 3
# Throw : 53
# Throw Value : 2
# Your Position After throw : 3
# Press Enter to Throw the Die
# Throw : 54
# Throw Value : 1
# Your Position After throw : 4
# Press Enter to Throw the Die
# Throw : 55
# Throw Value : 2
# Your Position After throw : 6
# Press Enter to Throw the Die
# Throw : 56
# Throw Value : 4
# Your Position After throw : 10
# Press Enter to Throw the Die
# Throw : 57
# Throw Value : 5
# Your Position After throw : 15
# Press Enter to Throw the Die
# Throw : 58
# Throw Value : 5
# Your Position After throw : 20
# Press Enter to Throw the Die
# Throw : 59
# Throw Value : 6
# Your Position After throw : 26
# Press Enter to Throw the Die
# Throw : 60
# Throw Value : 2
# Your Position After throw : 28
# Press Enter to Throw the Die
# Throw : 61
# Throw Value : 3
# Your Position After throw : 31
# Press Enter to Throw the Die
# Throw : 62
# Throw Value : 6
# Your Position After throw : 37
# Press Enter to Throw the Die
# Throw : 63
# Throw Value : 5
# Your Position After throw : 42
# Press Enter to Throw the Die
# Throw : 64
# Throw Value : 6
# Your Position After throw : 48
# Press Enter to Throw the Die
# Throw : 65
# Throw Value : 1
# Your Position After throw : 49
# Press Enter to Throw the Die
# Throw : 66
# Throw Value : 3
# Your Position After throw : 52
# Press Enter to Throw the Die
# Throw : 67
# Throw Value : 4
# Your Position After throw : 56
# Press Enter to Throw the Die
# Throw : 68
# Throw Value : 5
# Your Position After throw : 61
# Press Enter to Throw the Die
# Throw : 69
# Throw Value : 2
# Your Position After throw : 63
# Press Enter to Throw the Die
# Throw : 70
# Throw Value : 4
# Your Position After throw : 67
# Press Enter to Throw the Die
# Throw : 71
# Throw Value : 1
# Your Position After throw : 68
# Press Enter to Throw the Die
# Throw : 72
# Throw Value : 6
# Your Position After throw : 74
# Press Enter to Throw the Die
# In 77 there is a Ladder so you need to start from 92
# Throw : 73
# Throw Value : 3
# Your Position After throw : 92
# Press Enter to Throw the Die
# Throw : 74
# Throw Value : 6
# Your Position After throw : 98
# Press Enter to Throw the Die
# Throw Value : 3
# Your Position After throw : 98
# Press Enter to Throw the Die
# Throw Value : 3
# Your Position After throw : 98
# Press Enter to Throw the Die
# Throw Value : 6
# Your Position After throw : 98
# Press Enter to Throw the Die
# In 99 there is a snake so you need to start from 1
# Throw : 78
# Throw Value : 1
# Your Position After throw : 1
# Press Enter to Throw the Die
# Throw : 79
# Throw Value : 6
# Your Position After throw : 7
# Press Enter to Throw the Die
# Throw : 80
# Throw Value : 1
# Your Position After throw : 8
# Press Enter to Throw the Die
# In 13 there is a Ladder so you need to start from 67
# Throw : 81
# Throw Value : 5
# Your Position After throw : 67
# Press Enter to Throw the Die
# Throw : 82
# Throw Value : 3
# Your Position After throw : 70
# Press Enter to Throw the Die
# Throw : 83
# Throw Value : 6
# Your Position After throw : 76
# Press Enter to Throw the Die
# Throw : 84
# Throw Value : 2
# Your Position After throw : 78
# Press Enter to Throw the Die
# Throw : 85
# Throw Value : 2
# Your Position After throw : 80
# Press Enter to Throw the Die
# Throw : 86
# Throw Value : 2
# Your Position After throw : 82
# Press Enter to Throw the Die
# Throw : 87
# Throw Value : 3
# Your Position After throw : 85
# Press Enter to Throw the Die
# Throw : 88
# Throw Value : 3
# Your Position After throw : 88
# Press Enter to Throw the Die
# Throw : 89
# Throw Value : 6
# Your Position After throw : 94
# Press Enter to Throw the Die
# Throw : 90
# Throw Value : 2
# Your Position After throw : 96
# Press Enter to Throw the Die
# Throw Value : 5
# Your Position After throw : 96
# Press Enter to Throw the Die
# Throw Value : 5
# Your Position After throw : 96
# Press Enter to Throw the Die
# Throw : 93
# Throw Value : 4
# Your Position After throw : 100
# Total Rolls : 93

# %%
print(os.getcwd())  # It returns the current working directory
if not os.path.exists('OOPs'):
    os.mkdir('OOPs')
    print("File created succesfully !")
else:
    print("File already existed")
os.chdir('OOPs')
print(os.getcwd())
# Out:
# C:\Users\rajuk\Desktop\Practice for Codegnan\Python\classes
# File already existed
# C:\Users\rajuk\Desktop\Practice for Codegnan\Python\classes\OOPs

# %%
print(os.getcwd())
print(os.listdir('.'))
os.chdir('..')       # This changes the working directory as previous directory
print(os.getcwd())
# Out:
# C:\Users\rajuk\Desktop\Practice for Codegnan\Python\classes\OOPs
# []
# C:\Users\rajuk\Desktop\Practice for Codegnan\Python\classes
