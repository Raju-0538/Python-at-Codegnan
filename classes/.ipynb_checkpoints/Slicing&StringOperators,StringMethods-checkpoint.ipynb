# %%
print("hi")
# Out:
# hi

# %%
# indexing 
s = "Codegnan"
print(s[2])
print(s[-1])
# Out:
# d
# n

# %%
print(s[0:-1])
print(s[0:-5])
print(s[-4:-7:1])
print(s[0:-1:3])
print(s[-4:-7:-1])
print(s[5:100])
print(s[10:100])
print(s[::-1])
print(s[-3::-1])
print(s[-3::1])
# Out:
# Codegna
# Cod
#
# Cea
# ged
# nan
#
# nangedoC
# ngedoC
# nan

# %%
# empty string representation
# type() : this functions returns the objects datatype
s1 = ""
s2 = str()
print(type(s1))
print(type(s2))
# Out:
# <class 'str'>
# <class 'str'>

# %%
# String reading fom user
# input() : this function is used to read dynamically from user and this function by default read it as string data type
s = input()
print(type(s))
print(s)
# Out:
#  raju
# <class 'str'>
# raju

# %%
# String Operations 
# 1.String concatination (Using + Operator )
# 2.String Repetation (Using * Operator )
s1 = "code "
s2 = "gnan"
s1+s2
s1*4
# Out:
# 'code code code code '

# %%
s = "CodeGnan"
print(s[:1]+"z"+s[2:])
# Out:
# CzdeGnan

# %% [markdown]
# ## String Methods
# - Case conversion methods
#   - Upper() : It converts entire string into upper case
#   - Lower() : It converts entire string into lower case
#   - Title() : It cinverts the first letter of every word into upper and remining lower
#   - Swapcase() : It converts uppercase into lowercase and lower into upper
#   - Capitalize() : It converts first character into uppper case and remining into lower case

# %%
s = "the Sky is Blue and Ocean is blue"
print(s.upper())
print(s.lower())
print(s.title())
print(s.swapcase())
print(s.capitalize())
# Out:
# THE SKY IS BLUE AND OCEAN IS BLUE
# the sky is blue and ocean is blue
# The Sky Is Blue And Ocean Is Blue
# THE sKY IS bLUE AND oCEAN IS BLUE
# The sky is blue and ocean is blue

# %% [markdown]
# - Remove white space or pattern at end of string
#    - strip() : By default it removes the white space at both ends of string
#    - lstrip() : It removes the white space at left side of string
#    - rstrip() : It removes the white space at right side of string

# %%
s = "         codegnan            "
print(s)
print(s.strip())
print(s.lstrip())
print(s.rstrip())
# Out:
#          codegnan
# codegnan
# codegnan
#          codegnan

# %%
s = "@@@@codegnan @@@@@"
print(s)
print(s.strip('@'))
print(s.lstrip('@'))
print(s.rstrip('@'))
# Out:
#      @@@@codegnan @@@@@
#      @@@@codegnan @@@@@
#      @@@@codegnan @@@@@
#      @@@@codegnan @@@@@

# %%
# split() : It splits the entire string into list of substrings based on the specified seperator.
# buy default it splits at space
s = "the Sky is Blue and Ocean is blue"
print(s.split())
print(s.split("is"))
print(s.split("e"))
# Out:
# ['the', 'Sky', 'is', 'Blue', 'and', 'Ocean', 'is', 'blue']
# ['the Sky ', ' Blue and Ocean ', ' blue']
# ['th', ' Sky is Blu', ' and Oc', 'an is blu', '']

# %%
# ' sep'.join(iterable) : It joins all the iterable elements with the separator
w = ['the', 'Sky', 'is', 'Blue', 'and', 'Ocean', 'is', 'blue']
print("".join(w))
print(" ".join(w))
print("-".join(w))
# Out:
# theSkyisBlueandOceanisblue
# the Sky is Blue and Ocean is blue
# the-Sky-is-Blue-and-Ocean-is-blue

# %% [markdown]
# ### substring index finding
# - index(substring) : If substring is exists in string, it returns the first occurence of substring position otherwise 'Value Error'
# - find(substring) : If substring is exists in string, it returns the first occurence of substring position otherwise '-1'

# %%
s = "the Sky is Blue and Ocean is blue"
print(s.index('is'))
print(s.index('z'))
# Out:
# 8
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 3
#       1 s = "the Sky is Blue and Ocean is blue"
#       2 print(s.index('is'))
# ----> 3 print(s.index('z'))
#
# ValueError: substring not found

# %%
s = "the Sky is Blue and Ocean is blue"
print(s.find('is'))
print(s.find('z'))
print(s.find('is',10)) #It starts checking from 10th position
print(s.find('s',10))
print(s.find('e',-5))
# Out:
# 8
# -1
# 26
# 27
# 32

# %%
# count(substring) : It returns the total non-overlapping occurances of substring
s = "ABCBCBCbbaabb"
print(s.count("B"))
print(s.count("BCB"))
print(s.upper().count("B"))
# Out:
# 3
# 1
# 7
